# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
analysis = pd.read_excel(r'C:\Users\Admin\Desktop\student marks.xlsx',sheet_name = 'Sheet2')
analysis
# Out:
#     PropertyState  Furnishings  Housekeeping  Maintenance  Office Supplies  \
# 0         Arizona        12426          2432         4756             1526
# 1      California        23167          4307        11274             2538
# 2        Colorado        10581          2546         4363             1739
# 3         Florida        12927          1730         2908              935
# 4         Georgia        10272          2424         3573             1039
# 5        Illinois        11292          2627         6728             1136
# 6       Louisiana        10568          2410         5328             1541
# 7   Massachusetts        12176          2132         4403             1206
# 8        Missouri        14847          2818         6339             1081
# 9          Nevada         9681          2642         5753             1411
# 10       New York         9151          3271         2846             1310
# ...

# %%
pivot = analysis.pivot_table(index = 'PropertyState', columns = 'Furnishings', values ='All', aggfunc = sum )
pivot
# Out:
# Furnishings     8688     9151     9681     10272    10332    10467    10568   \
# PropertyState
# All                NaN      NaN      NaN      NaN      NaN      NaN      NaN
# Arizona            NaN      NaN      NaN      NaN      NaN      NaN      NaN
# California         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# Colorado           NaN      NaN      NaN      NaN      NaN      NaN      NaN
# Florida            NaN      NaN      NaN      NaN      NaN      NaN      NaN
# Georgia            NaN      NaN      NaN  25133.0      NaN      NaN      NaN
# Illinois           NaN      NaN      NaN      NaN      NaN      NaN      NaN
# Louisiana          NaN      NaN      NaN      NaN      NaN      NaN  27483.0
# Massachusetts      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# Missouri           NaN      NaN      NaN      NaN      NaN      NaN      NaN
# Nevada             NaN      NaN  25557.0      NaN      NaN      NaN      NaN
# ...

# %%
pivot
# Out:
# Furnishings     8688     9151     9681     10272    10332    10467    10568   \
# PropertyState
# All                NaN      NaN      NaN      NaN      NaN      NaN      NaN
# Arizona            NaN      NaN      NaN      NaN      NaN      NaN      NaN
# California         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# Colorado           NaN      NaN      NaN      NaN      NaN      NaN      NaN
# Florida            NaN      NaN      NaN      NaN      NaN      NaN      NaN
# Georgia            NaN      NaN      NaN  25133.0      NaN      NaN      NaN
# Illinois           NaN      NaN      NaN      NaN      NaN      NaN      NaN
# Louisiana          NaN      NaN      NaN      NaN      NaN      NaN  27483.0
# Massachusetts      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# Missouri           NaN      NaN      NaN      NaN      NaN      NaN      NaN
# Nevada             NaN      NaN  25557.0      NaN      NaN      NaN      NaN
# ...

# %%
names = pd.DataFrame({'Name' : list('ABCDE'), 'AGE':[11,12,13,14,15]})
names
# Out:
#   Name  AGE
# 0    A   11
# 1    B   12
# 2    C   13
# 3    D   14
# 4    E   15

# %%
names1 = pd.DataFrame({'name': list('FGH'), 'age' : [16,17,18]})
names1
# Out:
#   name  age
# 0    F   16
# 1    G   17
# 2    H   18

# %%
names.merge(names1, left_on = 'Name' , right_on = 'name', how = 'left')
# Out:
#   Name  AGE name  age
# 0    A   11  NaN  NaN
# 1    B   12  NaN  NaN
# 2    C   13  NaN  NaN
# 3    D   14  NaN  NaN
# 4    E   15  NaN  NaN

# %%
names.merge(names1, left_on = 'Name' , right_on = 'name', how = 'right')
# Out:
#   Name  AGE name  age
# 0  NaN  NaN    F   16
# 1  NaN  NaN    G   17
# 2  NaN  NaN    H   18

# %%
names.merge(names1, left_on = 'Name' , right_on = 'name', how = 'inner')
# Out:
# Empty DataFrame
# Columns: [Name, AGE, name, age]
# Index: []

# %%
names.merge(names1, left_on = 'Name' , right_on = 'name', how = 'outer')
# Out:
#   Name   AGE name   age
# 0    A  11.0  NaN   NaN
# 1    B  12.0  NaN   NaN
# 2    C  13.0  NaN   NaN
# 3    D  14.0  NaN   NaN
# 4    E  15.0  NaN   NaN
# 5  NaN   NaN    F  16.0
# 6  NaN   NaN    G  17.0
# 7  NaN   NaN    H  18.0

# %%
catsales = pd.read_excel(r'C:\Users\Admin\Desktop\student marks.xlsx',sheet_name = 'Sheet3')
catsales
# Out:
#    ProductCategory   sales
# 0      Furnishings  226181
# 1     Housekeeping   50410
# 2      Maintenance   93575
# 3  Office Supplies   29550
# 4     Public Areas  132480

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.plot(catsales['ProductCategory'],catsales['sales'])

# %%
plt.plot(catsales['ProductCategory'],catsales['sales'])

# %%
plt.figure(figsize = (10, 3))
plt.title('ProductCategory&sales')
plt.plot(catsales['ProductCategory'],catsales['sales'],'r')
plt.xlabel('ProductCategory')
plt.ylabel('sales')
plt.ylim(1000,1000000)
# Out:
# (1000.0, 1000000.0)

# %%
plt.figure(figsize = (10, 3))
plt.title('ProductCategory&sales')
plt.plot(catsales['ProductCategory'],catsales['sales'],'orange')
plt.xlabel('ProductCategory')
plt.ylabel('sales')
plt.ylim(1000,1000000)
# Out:
# (1000.0, 1000000.0)

# %%
plt.figure(figsize = (10, 3))
plt.title('ProductCategory&sales')
plt.plot(catsales['ProductCategory'],catsales['sales'],'k+')
plt.xlabel('ProductCategory')
plt.ylabel('sales')
# Out:
# Text(0, 0.5, 'sales')

# %%
plt.figure(figsize = (10, 3))
plt.title('ProductCategory&sales')
plt.plot(catsales['ProductCategory'],catsales['sales'],'go')
plt.xlabel('ProductCategory')
plt.ylabel('sales')
# Out:
# Text(0, 0.5, 'sales')

# %%
plt.figure(figsize = (10, 3))
plt.title('ProductCategory&sales')
plt.plot(catsales['ProductCategory'],catsales['sales'],'g--o')
plt.xlabel('ProductCategory')
plt.ylabel('sales')
# Out:
# Text(0, 0.5, 'sales')

# %%
plt.figure(figsize = (10, 3))
plt.title('ProductCategory&sales')
plt.plot(catsales['ProductCategory'],catsales['sales'],'b--D')
plt.xlabel('ProductCategory')
plt.ylabel('sales')
# Out:
# Text(0, 0.5, 'sales')

# %%
plt.figure(figsize = (10, 3))
plt.title('ProductCategory&sales')
plt.plot(catsales['ProductCategory'],catsales['sales'],'r--D')
plt.xlabel('ProductCategory')
plt.ylabel('sales')
# Out:
# Text(0, 0.5, 'sales')

# %%
plt.figure(figsize = (10, 3))
plt.title('ProductCategory&sales')
plt.plot(catsales['ProductCategory'],catsales['sales'],'r--D', mfc = 'orange', mec = 'g')
plt.xlabel('ProductCategory')
plt.ylabel('sales')
# Out:
# Text(0, 0.5, 'sales')

# %%
plt.figure(figsize = (14, 4))
plt.title('ProductCategory&sales')
plt.plot(catsales['ProductCategory'],catsales['sales'],'r--D', mfc = 'orange', mec = 'g')
plt.xlabel('ProductCategory')
plt.ylabel('sales')
plt.legend(labels = ['sales'])
plt.savefig('figure 1.jpg',dpi = 900)

# %%
plt.savefig('catsales')

# %%
os.getcwd
# Out:
# <function nt.getcwd()>

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'catsales.png',
#  'CSV File.csv',
#  'Day 1 - Intro to Python.ipynb',
#  'Day 10 - NumPy and Pandas.ipynb',
#  'Day 10 - NumPy and Pandas.py',
#  'Day 11 - Pandas.ipynb',
#  'Day 11 - Pandas.py',
#  'Day 12 - Pandas, Matplot and Seaborn.ipynb',
#  'Day 12 - Pandas, Matplot and Seaborn.py',
#  'Day 2 - Data Types and Data Structures.ipynb',
#  'Day 2 - Data Types and Data Structures.py',
#  'Day 3 - Data Structures.ipynb',
#  'Day 3 - Data Structures.py',
#  'Day 4 - Data Structures, Operators, Input, Output and Format.ipynb',
#  'Day 4 - Data Structures, Operators, Input, Output and Format.py',
#  'Day 5 - Conditionals and Loops.ipynb',
#  'Day 5 - Conditionals and Loops.py',
#  'Day 5 - Conditionals, Loops and Comprehensions.ipynb',
#  'Day 6 - Functions and Hands-on.ipynb',
#  'Day 6 - Functions and Hands-on.py',
#  'Day 6 - Functions.ipynb',
#  'Day 6 - Hands-on.ipynb',
#  'Day 6 - Hands-on.py',
# ...

# %%
pd.read_png('figure 1.png')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 pd.read_png('figure 1.png')
#
# File ~\anaconda3\Lib\site-packages\pandas\__init__.py:264, in __getattr__(name)
#     260     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     262     return _SparseArray
# --> 264 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'read_png'

# %%
catsales
# Out:
#    ProductCategory   sales
# 0      Furnishings  226181
# 1     Housekeeping   50410
# 2      Maintenance   93575
# 3  Office Supplies   29550
# 4     Public Areas  132480

# %%
plt.figure(figsize = [15,6])
plt.bar(catsales['ProductCategory'],catsales['sales'])
# Out:
# <BarContainer object of 5 artists>

# %%
plt.figure(figsize = [15,6])
plt.bar(catsales['ProductCategory'],catsales['sales'],color = 'r')
# Out:
# <BarContainer object of 5 artists>

# %%
plt.figure(figsize = [15,6])
plt.bar(catsales['ProductCategory'],catsales['sales'],color = ['r','g','k','orange','b'])
# Out:
# <BarContainer object of 5 artists>

# %%
plt.figure(figsize = [15,6])
plt.barh(catsales['ProductCategory'],catsales['sales'],color = ['r','g','k','orange','b'])
# Out:
# <BarContainer object of 5 artists>

# %%
catsales
# Out:
#    ProductCategory   sales
# 0      Furnishings  226181
# 1     Housekeeping   50410
# 2      Maintenance   93575
# 3  Office Supplies   29550
# 4     Public Areas  132480

# %%
catsales['sales'].describe()
# Out:
# count         5.000000
# mean     106439.200000
# std       77834.648298
# min       29550.000000
# 25%       50410.000000
# 50%       93575.000000
# 75%      132480.000000
# max      226181.000000
# Name: sales, dtype: float64

# %%
plt.hist(catsales['sales'])
# Out:
# (array([1., 1., 0., 1., 0., 1., 0., 0., 0., 1.]),
#  array([ 29550. ,  49213.1,  68876.2,  88539.3, 108202.4, 127865.5,
#         147528.6, 167191.7, 186854.8, 206517.9, 226181. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(catsales['sales'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x218cf1e7bd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x218cea3c790>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x218cea1c650>],
#  'medians': [<matplotlib.lines.Line2D at 0x218cea3e290>],
#  'fliers': [<matplotlib.lines.Line2D at 0x218cea2cf50>],
#  'means': []}

# %%
plt.violinplot(catsales['sales']);

# %%
catsales
# Out:
#    ProductCategory   sales
# 0      Furnishings  226181
# 1     Housekeeping   50410
# 2      Maintenance   93575
# 3  Office Supplies   29550
# 4     Public Areas  132480

# %%
plt.pie(catsales['sales'], labels = catsales['ProductCategory']);

# %%
catsales
# Out:
#    ProductCategory   sales
# 0      Furnishings  226181
# 1     Housekeeping   50410
# 2      Maintenance   93575
# 3  Office Supplies   29550
# 4     Public Areas  132480

# %%
sns.barplot(x = 'ProductCategory', y = 'sales', data = catsales);

# %%
pip install imdlib
# Out:
# ...
#   Obtaining dependency information for imdlib from https://files.pythonhosted.org/packages/f9/76/bb71caf2ae9aee9235aeaa0a675862d04ee07d41c3a7c292d296176497c3/imdlib-0.1.19-py3-none-any.whl.metadata
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import imdlib as imd

# %%
imd
# Out:
# <module 'imdlib' from 'C:\\Users\\Admin\\anaconda3\\Lib\\site-packages\\imdlib\\__init__.py'>
